# %% [markdown]
# ### Create Catalog

# %%
# %sql
CREATE CATALOG cars_catalog MANAGED LOCATION 'abfss://automotive-sales@automotivesalessa.dfs.core.windows.net/';

# %% [markdown]
# Create Schemas

# %%
# %sql
CREATE SCHEMA cars_catalog.silver;

# %%
# %sql
CREATE SCHEMA cars_catalog.gold;
